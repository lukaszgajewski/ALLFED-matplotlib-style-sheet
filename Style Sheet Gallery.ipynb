# %%
import matplotlib.pyplot as plt
import random
plt.style.use("ALLFED.mplstyle")

# %%
x = [random.random() for i in range(20)]
y = [random.random() for i in range(20)]
# Out:
# [0.9860548485496982,
#  0.6491881763004158,
#  0.9107304787472383,
#  0.5801751890270389,
#  0.7366921598474424,
#  0.039461708054290945,
#  0.4229407288554696,
#  0.20571173489092698,
#  0.8124855488102734,
#  0.31227250600892187,
#  0.20859708356257978,
#  0.6108952896050271,
#  0.8882549199525208,
#  0.9735298851662957,
#  0.5417136249960706,
#  0.04695345565979636,
#  0.800663358421323,
#  0.7966794445852973,
#  0.9812156821154538,
#  0.3453909806958406]

# %%
plt.plot(x)

# %%
plt.scatter(x,y)
